# %% [markdown]
# # Handling missing data

# %% [markdown]
# This notebook will only use TimeBasedCesnetDataset, but all methods work almost the same way for SeriesBasedCesnetDataset.

# %% [markdown]
# ### Import

# %%
import logging
import numpy as np

from cesnet_tszoo.utils.enums import AgreggationType, SourceType, FillerType, DatasetType
from cesnet_tszoo.datasets import CESNET_TimeSeries24
from cesnet_tszoo.configs import TimeBasedConfig # Time based dataset MUST use TimeBasedConfig

from cesnet_tszoo.utils.filler import Filler # For creating custom Filler

# %% [markdown]
# ### Setting logger

# %%
logging.basicConfig(
    level=logging.INFO,
    format="[%(asctime)s][%(name)s][%(levelname)s] - %(message)s")

# %% [markdown]
# ### Preparing dataset

# %%
time_based_dataset = CESNET_TimeSeries24.get_dataset(data_root="/some_directory/", source_type=SourceType.IP_ADDRESSES_SAMPLE, aggregation=AgreggationType.AGG_10_MINUTES, dataset_type=DatasetType.TIME_BASED, display_details=True)
# Out:
# [2025-08-26 09:15:49,907][wrapper_dataset][INFO] - Dataset is time-based. Use cesnet_tszoo.configs.TimeBasedConfig
# Dataset details:
#
#     AgreggationType.AGG_10_MINUTES
#         Time indices: range(0, 40297)
#         Datetime: (datetime.datetime(2023, 10, 9, 0, 3, 49, tzinfo=datetime.timezone.utc), datetime.datetime(2024, 7, 14, 21, 50, 52, tzinfo=datetime.timezone.utc))
#
#     SourceType.IP_ADDRESSES_SAMPLE
#         Time series indices: [ 11  20 101 103 118 ... 2003134 2008461 2011839 2022235 2044888], Length=1000; use 'get_available_ts_indices' for full list
#         Features with default values: {'n_flows': 0, 'n_packets': 0, 'n_bytes': 0, 'n_dest_ip': 0, 'n_dest_asn': 0, 'n_dest_ports': 0, 'tcp_udp_ratio_packets': 0.5, 'tcp_udp_ratio_bytes': 0.5, 'dir_ratio_packets': 0.5, 'dir_ratio_bytes': 0.5, 'avg_duration': 0, 'avg_ttl': 0}
#
#         Additional data: ['ids_relationship', 'weekends_and_holidays']

# %% [markdown]
# ### Default values

# %% [markdown]
# - Default values are set to missing values before filler is used.
# - You can change used default values later with `update_dataset_config_and_initialize` or `set_default_values`.

# %% [markdown]
# #### Using default

# %% [markdown]
# - Default values are provided from used dataset.
# - You can look at default values for each feature with `time_based_dataset.display_dataset_details()`.

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values="default")

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:49,912][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:49,967][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:49,971][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 398.43it/s]
# [2025-08-26 09:15:49,974][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [0. 0.]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: None
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      0.0        0.0
# 1   1200.0      1.0      0.0        0.0
# 2   1200.0      2.0      0.0        0.0
# 3   1200.0      3.0      0.0        0.0
# 4   1200.0      4.0      0.0        0.0
# 5   1200.0      5.0      0.0        0.0
# 6   1200.0      6.0      0.0        0.0
# 7   1200.0      7.0      0.0        0.0
# 8   1200.0      8.0      0.0        0.0
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      0.0        0.0
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      0.0        0.0
# 13  1200.0     13.0      0.0        0.0
# 14  1200.0     14.0      0.0        0.0
# 15  1200.0     15.0      0.0        0.0
# 16  1200.0     16.0      0.0        0.0
# 17  1200.0     17.0      0.0        0.0
# 18  1200.0     18.0      0.0        0.0
# 19  1200.0     19.0      0.0        0.0
# 20  1200.0     20.0      0.0        0.0
# 21  1200.0     21.0      0.0        0.0
# 22  1200.0     22.0      0.0        0.0
# 23  1200.0     23.0      0.0        0.0
# 24  1200.0     24.0      0.0        0.0
# 25  1200.0     25.0      0.0        0.0
# 26  1200.0     26.0      0.0        0.0
# 27  1200.0     27.0      0.0        0.0
# 28  1200.0     28.0      0.0        0.0
# 29  1200.0     29.0      0.0        0.0

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(default_values="default", workers=0)
# Or
time_based_dataset.set_default_values(default_values="default", workers=0)
# Out:
# [2025-08-26 09:15:50,001][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,054][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,057][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 997.22it/s]
# [2025-08-26 09:15:50,059][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,060][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,060][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,111][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,114][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:50,117][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,117][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,117][cesnet_dataset][INFO] - Default values has been changed successfuly.

# %% [markdown]
# #### Setting default_values as None

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=None)

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:50,122][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:50,173][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,176][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 998.64it/s]
# [2025-08-26 09:15:50,178][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [nan nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: None
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      NaN        NaN
# 1   1200.0      1.0      NaN        NaN
# 2   1200.0      2.0      NaN        NaN
# 3   1200.0      3.0      NaN        NaN
# 4   1200.0      4.0      NaN        NaN
# 5   1200.0      5.0      NaN        NaN
# 6   1200.0      6.0      NaN        NaN
# 7   1200.0      7.0      NaN        NaN
# 8   1200.0      8.0      NaN        NaN
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      NaN        NaN
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      NaN        NaN
# 13  1200.0     13.0      NaN        NaN
# 14  1200.0     14.0      NaN        NaN
# 15  1200.0     15.0      NaN        NaN
# 16  1200.0     16.0      NaN        NaN
# 17  1200.0     17.0      NaN        NaN
# 18  1200.0     18.0      NaN        NaN
# 19  1200.0     19.0      NaN        NaN
# 20  1200.0     20.0      NaN        NaN
# 21  1200.0     21.0      NaN        NaN
# 22  1200.0     22.0      NaN        NaN
# 23  1200.0     23.0      NaN        NaN
# 24  1200.0     24.0      NaN        NaN
# 25  1200.0     25.0      NaN        NaN
# 26  1200.0     26.0      NaN        NaN
# 27  1200.0     27.0      NaN        NaN
# 28  1200.0     28.0      NaN        NaN
# 29  1200.0     29.0      NaN        NaN

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(default_values=None, workers=0)
# Or
time_based_dataset.set_default_values(default_values=None, workers=0)
# Out:
# [2025-08-26 09:15:50,254][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,306][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,309][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 1000.79it/s]
# [2025-08-26 09:15:50,311][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,311][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,312][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,364][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,367][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 998.17it/s]
# [2025-08-26 09:15:50,369][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,369][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,370][cesnet_dataset][INFO] - Default values has been changed successfuly.

# %% [markdown]
# #### Setting default_values with single number

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=0)

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:50,374][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:50,426][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,429][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 999.60it/s]
# [2025-08-26 09:15:50,431][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [0. 0.]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: None
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      0.0        0.0
# 1   1200.0      1.0      0.0        0.0
# 2   1200.0      2.0      0.0        0.0
# 3   1200.0      3.0      0.0        0.0
# 4   1200.0      4.0      0.0        0.0
# 5   1200.0      5.0      0.0        0.0
# 6   1200.0      6.0      0.0        0.0
# 7   1200.0      7.0      0.0        0.0
# 8   1200.0      8.0      0.0        0.0
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      0.0        0.0
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      0.0        0.0
# 13  1200.0     13.0      0.0        0.0
# 14  1200.0     14.0      0.0        0.0
# 15  1200.0     15.0      0.0        0.0
# 16  1200.0     16.0      0.0        0.0
# 17  1200.0     17.0      0.0        0.0
# 18  1200.0     18.0      0.0        0.0
# 19  1200.0     19.0      0.0        0.0
# 20  1200.0     20.0      0.0        0.0
# 21  1200.0     21.0      0.0        0.0
# 22  1200.0     22.0      0.0        0.0
# 23  1200.0     23.0      0.0        0.0
# 24  1200.0     24.0      0.0        0.0
# 25  1200.0     25.0      0.0        0.0
# 26  1200.0     26.0      0.0        0.0
# 27  1200.0     27.0      0.0        0.0
# 28  1200.0     28.0      0.0        0.0
# 29  1200.0     29.0      0.0        0.0

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(default_values=0, workers=0)
# Or
time_based_dataset.set_default_values(default_values=0, workers=0)
# Out:
# [2025-08-26 09:15:50,452][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,506][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,509][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 1002.22it/s]
# [2025-08-26 09:15:50,511][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,512][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,512][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,564][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,568][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:50,570][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,570][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,570][cesnet_dataset][INFO] - Default values has been changed successfuly.

# %% [markdown]
# #### Setting default_values with list

# %% [markdown]
# - Position of values in list correspond to order of features in `features_to_take`.
# - Number of values in list must be equal to number of used features.

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=[1, None])

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:50,575][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:50,628][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,631][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 999.36it/s]
# [2025-08-26 09:15:50,633][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [ 1. nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: None
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      1.0        NaN
# 1   1200.0      1.0      1.0        NaN
# 2   1200.0      2.0      1.0        NaN
# 3   1200.0      3.0      1.0        NaN
# 4   1200.0      4.0      1.0        NaN
# 5   1200.0      5.0      1.0        NaN
# 6   1200.0      6.0      1.0        NaN
# 7   1200.0      7.0      1.0        NaN
# 8   1200.0      8.0      1.0        NaN
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      1.0        NaN
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      1.0        NaN
# 13  1200.0     13.0      1.0        NaN
# 14  1200.0     14.0      1.0        NaN
# 15  1200.0     15.0      1.0        NaN
# 16  1200.0     16.0      1.0        NaN
# 17  1200.0     17.0      1.0        NaN
# 18  1200.0     18.0      1.0        NaN
# 19  1200.0     19.0      1.0        NaN
# 20  1200.0     20.0      1.0        NaN
# 21  1200.0     21.0      1.0        NaN
# 22  1200.0     22.0      1.0        NaN
# 23  1200.0     23.0      1.0        NaN
# 24  1200.0     24.0      1.0        NaN
# 25  1200.0     25.0      1.0        NaN
# 26  1200.0     26.0      1.0        NaN
# 27  1200.0     27.0      1.0        NaN
# 28  1200.0     28.0      1.0        NaN
# 29  1200.0     29.0      1.0        NaN

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(default_values=[1, None], workers=0)
# Or
time_based_dataset.set_default_values(default_values=[1, None], workers=0)
# Out:
# [2025-08-26 09:15:50,654][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,706][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,709][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 998.88it/s]
# [2025-08-26 09:15:50,711][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,712][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,712][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,764][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,768][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:50,770][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,770][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,770][cesnet_dataset][INFO] - Default values has been changed successfuly.

# %% [markdown]
# #### Setting default_values with dictionary

# %% [markdown]
# - Dictionary must contain key and value for every feature in `features_to_take`.

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values={"n_flows" : 1, "n_packets": None})

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:50,775][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:50,827][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,830][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 999.12it/s]
# [2025-08-26 09:15:50,832][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [ 1. nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: None
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      1.0        NaN
# 1   1200.0      1.0      1.0        NaN
# 2   1200.0      2.0      1.0        NaN
# 3   1200.0      3.0      1.0        NaN
# 4   1200.0      4.0      1.0        NaN
# 5   1200.0      5.0      1.0        NaN
# 6   1200.0      6.0      1.0        NaN
# 7   1200.0      7.0      1.0        NaN
# 8   1200.0      8.0      1.0        NaN
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      1.0        NaN
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      1.0        NaN
# 13  1200.0     13.0      1.0        NaN
# 14  1200.0     14.0      1.0        NaN
# 15  1200.0     15.0      1.0        NaN
# 16  1200.0     16.0      1.0        NaN
# 17  1200.0     17.0      1.0        NaN
# 18  1200.0     18.0      1.0        NaN
# 19  1200.0     19.0      1.0        NaN
# 20  1200.0     20.0      1.0        NaN
# 21  1200.0     21.0      1.0        NaN
# 22  1200.0     22.0      1.0        NaN
# 23  1200.0     23.0      1.0        NaN
# 24  1200.0     24.0      1.0        NaN
# 25  1200.0     25.0      1.0        NaN
# 26  1200.0     26.0      1.0        NaN
# 27  1200.0     27.0      1.0        NaN
# 28  1200.0     28.0      1.0        NaN
# 29  1200.0     29.0      1.0        NaN

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(default_values={"n_flows" : 1, "n_packets": None}, workers=0)
# Or
time_based_dataset.set_default_values(default_values={"n_flows" : 1, "n_packets": None}, workers=0)
# Out:
# [2025-08-26 09:15:50,852][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,906][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,909][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:50,912][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,912][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,913][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:50,964][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:50,967][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:50,970][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:50,970][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:50,970][cesnet_dataset][INFO] - Default values has been changed successfuly.

# %% [markdown]
# ### Fillers

# %% [markdown]
# - Fillers are implemented as classes.
#     - You can create your own or use built-in one.
# - One filler per time series is created.
# - Filler is applied after default values and usually overrides them.
# - You can change used filler later with `update_dataset_config_and_initialize` or `apply_filler`.

# %% [markdown]
# #### Built-in

# %%
# Options

FillerType.FORWARD_FILLER
FillerType.LINEAR_INTERPOLATION_FILLER
FillerType.MEAN_FILLER
# Out:
# <FillerType.MEAN_FILLER: 'mean_filler'>

# %% [markdown]
# In example below, you can see how `ForwardFiller` fills missing values, except those at the beginning which values are defined by default_values.

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=None, fill_missing_with=FillerType.FORWARD_FILLER)

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:50,980][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:51,034][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,037][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:51,039][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [nan nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: forward_filler
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      NaN        NaN
# 1   1200.0      1.0      NaN        NaN
# 2   1200.0      2.0      NaN        NaN
# 3   1200.0      3.0      NaN        NaN
# 4   1200.0      4.0      NaN        NaN
# 5   1200.0      5.0      NaN        NaN
# 6   1200.0      6.0      NaN        NaN
# 7   1200.0      7.0      NaN        NaN
# 8   1200.0      8.0      NaN        NaN
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      4.0        4.0
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      6.0        6.0
# 13  1200.0     13.0      6.0        6.0
# 14  1200.0     14.0      6.0        6.0
# 15  1200.0     15.0      6.0        6.0
# 16  1200.0     16.0      6.0        6.0
# 17  1200.0     17.0      6.0        6.0
# 18  1200.0     18.0      6.0        6.0
# 19  1200.0     19.0      6.0        6.0
# 20  1200.0     20.0      6.0        6.0
# 21  1200.0     21.0      6.0        6.0
# 22  1200.0     22.0      6.0        6.0
# 23  1200.0     23.0      6.0        6.0
# 24  1200.0     24.0      6.0        6.0
# 25  1200.0     25.0      6.0        6.0
# 26  1200.0     26.0      6.0        6.0
# 27  1200.0     27.0      6.0        6.0
# 28  1200.0     28.0      6.0        6.0
# 29  1200.0     29.0      6.0        6.0

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(fill_missing_with=FillerType.FORWARD_FILLER, workers=0)
# Or
time_based_dataset.apply_filler(FillerType.FORWARD_FILLER, workers=0)
# Out:
# [2025-08-26 09:15:51,061][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:51,114][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,117][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 997.46it/s]
# [2025-08-26 09:15:51,119][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:51,119][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:51,120][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:51,173][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,176][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 997.93it/s]
# [2025-08-26 09:15:51,178][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:51,178][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:51,178][cesnet_dataset][INFO] - Filler has been changed successfuly.

# %% [markdown]
# #### Custom

# %% [markdown]
# You can create your own custom filler, which must derive from Filler base class.

# %%
class CustomFiller(Filler):
    def fill(self, batch_values: np.ndarray, existing_indices: np.ndarray, missing_indices: np.ndarray, **kwargs):
        batch_values[missing_indices] = -1

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=None, fill_missing_with=CustomFiller)

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:51,188][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:51,239][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,242][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# [2025-08-26 09:15:51,245][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [nan nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: CustomFiller (Custom)
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0     -1.0       -1.0
# 1   1200.0      1.0     -1.0       -1.0
# 2   1200.0      2.0     -1.0       -1.0
# 3   1200.0      3.0     -1.0       -1.0
# 4   1200.0      4.0     -1.0       -1.0
# 5   1200.0      5.0     -1.0       -1.0
# 6   1200.0      6.0     -1.0       -1.0
# 7   1200.0      7.0     -1.0       -1.0
# 8   1200.0      8.0     -1.0       -1.0
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0     -1.0       -1.0
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0     -1.0       -1.0
# 13  1200.0     13.0     -1.0       -1.0
# 14  1200.0     14.0     -1.0       -1.0
# 15  1200.0     15.0     -1.0       -1.0
# 16  1200.0     16.0     -1.0       -1.0
# 17  1200.0     17.0     -1.0       -1.0
# 18  1200.0     18.0     -1.0       -1.0
# 19  1200.0     19.0     -1.0       -1.0
# 20  1200.0     20.0     -1.0       -1.0
# 21  1200.0     21.0     -1.0       -1.0
# 22  1200.0     22.0     -1.0       -1.0
# 23  1200.0     23.0     -1.0       -1.0
# 24  1200.0     24.0     -1.0       -1.0
# 25  1200.0     25.0     -1.0       -1.0
# 26  1200.0     26.0     -1.0       -1.0
# 27  1200.0     27.0     -1.0       -1.0
# 28  1200.0     28.0     -1.0       -1.0
# 29  1200.0     29.0     -1.0       -1.0

# %% [markdown]
# Or later with:

# %%
time_based_dataset.update_dataset_config_and_initialize(fill_missing_with=CustomFiller, workers=0)
# Or
time_based_dataset.apply_filler(CustomFiller, workers=0)
# Out:
# [2025-08-26 09:15:51,267][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:51,319][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,322][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 664.29it/s]
# [2025-08-26 09:15:51,324][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:51,325][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:51,325][cesnet_dataset][INFO] - Re-initialization is required.
# [2025-08-26 09:15:51,377][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,380][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 1000.55it/s]
# [2025-08-26 09:15:51,382][cesnet_dataset][INFO] - Config initialized successfully.
# [2025-08-26 09:15:51,382][cesnet_dataset][INFO] - Configuration has been changed successfuly.
# [2025-08-26 09:15:51,384][cesnet_dataset][INFO] - Filler has been changed successfuly.

# %% [markdown]
# #### Only for TimeBasedCesnetDataset

# %% [markdown]
# Values are carried over from train -> val -> test. Look below at example.

# %%
config = TimeBasedConfig(ts_ids=[1200], train_time_period=range(0, 30), test_time_period=range(30, 80), features_to_take=['n_flows', 'n_packets'],
                         default_values=None, fill_missing_with=FillerType.FORWARD_FILLER)

time_based_dataset.set_dataset_config_and_initialize(config, display_config_details=True, workers=0)
# Out:
# [2025-08-26 09:15:51,388][time_config][INFO] - Quick validation succeeded.
# [2025-08-26 09:15:51,441][time_config][INFO] - Finalization and validation completed successfully.
# [2025-08-26 09:15:51,444][cesnet_dataset][INFO] - Updating config on train/val/test/all and selected time series.
# 100%|██████████| 1/1 [00:00<00:00, 997.93it/s]
# [2025-08-26 09:15:51,446][cesnet_dataset][INFO] - Config initialized successfully.
# Config Details
#     Used for database: CESNET-TimeSeries24
#     Aggregation: AgreggationType.AGG_10_MINUTES
#     Source: SourceType.IP_ADDRESSES_SAMPLE
#
#     Time series
#         Time series IDS: [1200], Length=1
#     Time periods
#         Train time periods: range(0, 30)
#         Val time periods: None
#         Test time periods: range(30, 80)
#         All time periods: range(0, 80)
#     Features
#         Taken features: ['n_flows', 'n_packets']
#         Default values: [nan nan]
#         Time series ID included: True
#         Time included: True
#         Time format: TimeFormat.ID_TIME
#     Sliding window
#         Sliding window size: None
#         Sliding window prediction size: None
#         Sliding window step size: 1
#         Set shared size: 0
#     Fillers
#         Filler type: forward_filler
#     Transformers
#         Transformer type: None
#     Anomaly handler
#         Anomaly handler type: None
#     Batch sizes
#         Train batch size: 32
#         Val batch size: 64
#         Test batch size: 128
#         All batch size: 128
#     Default workers
#         Init worker count: 4
#         Train worker count: 4
#         Val worker count: 3
#         Test worker count: 2
#         All worker count: 4
#     Other
#         Nan threshold: 1.0
#         Random state: None
#         Version: 0.1.3

# %%
time_based_dataset.get_train_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0      0.0      NaN        NaN
# 1   1200.0      1.0      NaN        NaN
# 2   1200.0      2.0      NaN        NaN
# 3   1200.0      3.0      NaN        NaN
# 4   1200.0      4.0      NaN        NaN
# 5   1200.0      5.0      NaN        NaN
# 6   1200.0      6.0      NaN        NaN
# 7   1200.0      7.0      NaN        NaN
# 8   1200.0      8.0      NaN        NaN
# 9   1200.0      9.0      4.0        4.0
# 10  1200.0     10.0      4.0        4.0
# 11  1200.0     11.0      6.0        6.0
# 12  1200.0     12.0      6.0        6.0
# 13  1200.0     13.0      6.0        6.0
# 14  1200.0     14.0      6.0        6.0
# 15  1200.0     15.0      6.0        6.0
# 16  1200.0     16.0      6.0        6.0
# 17  1200.0     17.0      6.0        6.0
# 18  1200.0     18.0      6.0        6.0
# 19  1200.0     19.0      6.0        6.0
# 20  1200.0     20.0      6.0        6.0
# 21  1200.0     21.0      6.0        6.0
# 22  1200.0     22.0      6.0        6.0
# 23  1200.0     23.0      6.0        6.0
# 24  1200.0     24.0      6.0        6.0
# 25  1200.0     25.0      6.0        6.0
# 26  1200.0     26.0      6.0        6.0
# 27  1200.0     27.0      6.0        6.0
# 28  1200.0     28.0      6.0        6.0
# 29  1200.0     29.0      6.0        6.0

# %% [markdown]
# You can see that values for n_flows and n_packets were carried over from train to test.

# %%
time_based_dataset.get_test_df(workers=0).iloc[:30]
# Out:
#      id_ip  id_time  n_flows  n_packets
# 0   1200.0     30.0      6.0        6.0
# 1   1200.0     31.0      6.0        6.0
# 2   1200.0     32.0      6.0        6.0
# 3   1200.0     33.0      6.0        6.0
# 4   1200.0     34.0      6.0        6.0
# 5   1200.0     35.0      6.0        6.0
# 6   1200.0     36.0      6.0        6.0
# 7   1200.0     37.0      6.0        6.0
# 8   1200.0     38.0      6.0        6.0
# 9   1200.0     39.0      6.0        6.0
# 10  1200.0     40.0      6.0        6.0
# 11  1200.0     41.0      6.0        6.0
# 12  1200.0     42.0      6.0        6.0
# 13  1200.0     43.0      6.0        6.0
# 14  1200.0     44.0      6.0        6.0
# 15  1200.0     45.0      6.0        6.0
# 16  1200.0     46.0      6.0        6.0
# 17  1200.0     47.0      6.0        6.0
# 18  1200.0     48.0      6.0        6.0
# 19  1200.0     49.0      6.0        6.0
# 20  1200.0     50.0      6.0        6.0
# 21  1200.0     51.0      6.0        6.0
# 22  1200.0     52.0      6.0        6.0
# 23  1200.0     53.0      6.0        6.0
# 24  1200.0     54.0      6.0        6.0
# 25  1200.0     55.0      6.0        6.0
# 26  1200.0     56.0      6.0        6.0
# 27  1200.0     57.0      2.0        2.0
# 28  1200.0     58.0      2.0        2.0
# 29  1200.0     59.0      2.0        2.0
